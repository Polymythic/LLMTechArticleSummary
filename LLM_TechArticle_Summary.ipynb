# %%
# imports

import os
import requests
from dotenv import load_dotenv
from bs4 import BeautifulSoup
from IPython.display import Markdown, display
from openai import OpenAI

# %%
# Load environment variables in a file called .env

load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

# Check the keys
def verify_api_key():
    if not api_key:
        print("No API key was found - please head over to the troubleshooting notebook in this folder to identify & fix!")
    elif not api_key.startswith("sk-proj-"):
        print("An API key was found, but it doesn't start sk-proj-; please check you're using the right key - see troubleshooting notebook")
    elif api_key.strip() != api_key:
        print("An API key was found, but it looks like it might have space or tab characters at the start or end - please remove them - see troubleshooting notebook")
    else:
        print("API key found and looks good so far!")
# Out:
# API key found and looks good so far!

# %%
# Verify we have the proper looking key
verify_api_key()

# Create an OpenAI client
openai = OpenAI()

# %%
# Some websites need you to use proper headers when fetching them:
headers = {
 "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0.0.0 Safari/537.36"
}

class Website:
    '''Class Website to represent a webpage'''

    def __init__(self, url):
        """
        Create this Website object from the given url using the BeautifulSoup library
        """
        self.url = url
        self.text = "no data"
  

    def getWebsiteData(self):
        response = requests.get(self.url, headers=headers)
        self.soup = BeautifulSoup(response.content, 'html.parser')
        self.title = self.soup.title.string if self.soup.title else "No title found"
        for irrelevant in self.soup.body(["script", "style", "img", "input"]):
            irrelevant.decompose()
        self.text = self.soup.body.get_text(separator="\n", strip=True)


    def getSoup(self): 
        return self.soup

# %%
# Define our system prompt for the initial ingestion of the web pages
system_prompt = "You are an assistant that analyzes the contents of a website \
and provides a short summary, ignoring text that might be navigation related. \
Respond in markdown."

# %%
def generate_llm_messages_for(website):
    return [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt_for(website)}
    ]

# %%
def summarizeWebsite(url):
    website = Website(url)
    website.getWebsiteData()
    response = openai.chat.completions.create(
        model = "gpt-4o-mini",
        messages = generate_llm_messages_for(website)
    )
    return response.choices[0].message.content

# %%
techSitesToVisit = ["https://cnn.com/business/tech",
                    "https://techcrunch.com",   
                    "https://theverge.com",
                    "https://wired.com",
                    "https://engadget.com",
                    "https://thenextweb.com",
                    "https://arstechnica.com"]

summaries = []

for techSite in techSitesToVisit:
    summary = summarizeWebsite(techSite)
    summaries.append(summary)
    print(summary)
# Out:
# # Summary of Tech | CNN Business
#
# The **Tech | CNN Business** section focuses on the latest developments and trends in technology and business, featuring articles on prominent companies, innovations, and market dynamics.
#
# ## Latest News Highlights
#
# - **Texas Instruments** announced an investment of over **$60 billion** to expand semiconductor manufacturing in the US.
# - **Meta** is reportedly offering **$100 million** to poach employees from rival companies.
# - **Taiwan** has placed companies linked to China's AI ambitions on an export control list.
# - **Google, Meta, and Snap** are exploring new technologies believed to be the next big thing in tech.
# - **Nvidia** is excluding China from its future forecasts due to US chip export controls.
# - **Disney and Universal** have initiated legal action against the AI photo generator **Midjourney**, alleging copyright infringement.
#
# This section also addresses ongoing issues such as internet outages affecting major companies and discussions around regulatory impacts on advertising and technology practices. Overall, it serves as a resource for those interested in the intersection of technology and business.
# # TechCrunch | Startup and Technology News
#
# TechCrunch is a leading source for information on startups and technology, providing the latest news and insights across various sectors including AI, apps, security, venture capital, and transportation. The site features coverage of significant events, trends, and innovations in the tech industry.
#
# ## Recent Headlines
# - **OpenAI Oversight**: "The ‘OpenAI Files’" suggests the need for regulatory oversight in the pursuit of artificial general intelligence (AGI).
# - **Rebooted Digg**: An exclusive look at the redesigned Digg platform has been presented.
# - **Internet Disruptions in Iran**: Web monitoring firms report widespread internet failures across Iran.
# - **Robotaxi Developments**: Amazon's Zoox has opened its first major production facility for robotaxis.
# - **Crypto Exchange Hacks**: A major Iranian crypto exchange was hacked, leading to significant financial losses.
#
# ## Startup Highlights
# - **Grifin**: A startup that has raised $11 million to simplify investing for female users.
# - **Seed to Series C Insights**: A new report discusses what venture capitalists are seeking in AI startups.
#
# ## Additional News
# - **IoT and Security**: Various cyber threats, including hacks affecting Iranian finance, highlight ongoing security concerns.
# - **Transportation Innovations**: Waymo is expanding its robotaxi services to New York City.
#
# TechCrunch remains an essential resource for entrepreneurs, investors, and anyone interested in the evolving technology landscape.
# # Summary of The Verge
#
# **The Verge** is a technology news and media website that covers a wide array of topics including technology, science, entertainment, and AI. The site offers in-depth reviews, features, and articles on emerging tech trends and products, along with entertainment and cultural commentary.
#
# ## Recent News Highlights
#
# 1. **Framework Laptop 12 Review**:
#    - A detailed examination of the Framework Laptop 12, highlighting its unique plastic build quality.
#
# 2. **Google's AI Voice Chats**:
#    - Google is testing real-time AI voice chats in its search functionality, aiming to enhance user interaction.
#
# 3. **Social Media Warning Labels**:
#    - New York has advanced a bill that mandates warning labels on social media platforms regarding potential mental health issues.
#
# 4. **Apple Patent Case Update**:
#    - Apple successfully overturned a $300 million patent loss involving Optis Wireless Technology, leading to a new trial.
#
# 5. **Waymo Robotaxis in NYC**:
#    - Waymo plans to reintroduce its robotaxi service in New York City.
#
# 6. **Amazon Job Cuts Due to AI**:
#    - Amazon's CEO announced layoffs due to the increased efficiency gained from AI technologies.
#
# 7. **Honda's Reusable Rocket Launch**:
#    - Honda successfully launched and landed its reusable rocket, marking a significant achievement in aerospace technology.
#
# The Verge continues to be a go-to source for tech enthusiasts, offering timely updates and comprehensive analyses of major technology-related developments.
# # WIRED Website Summary
#
# WIRED is an online magazine that provides the latest news and insights in technology, science, culture, and business. It explores how technological advancements shape various aspects of modern life, offering a platform for discussions on innovation and ideas that define the future.
#
# ## Recent Highlights
#
# - **"How to Win a Fight"**: A guide discussing the importance of choosing battles wisely.
# - **Steroid Olympics**: An exploration into the controversial Enhanced Games, requiring significant resources and support to implement.
# - **US Supreme Court Decision**: It upheld Tennessee's ban on gender-affirming care for minors, reflecting ongoing debates in US politics.
# - **Cybersecurity News**: Coverage on Israel-linked hackers impacting Iran’s financial systems.
# - **Regenerative Medicine**: Discovery related to axolotls reveals insights into potential advancements in human regenerative therapies.
#
# ## Other Notable Articles
#
# - Analysis of far-right conspiracy theories surrounding recent violent incidents in the US.
# - Review of AI's influence on disinformation strategies during protests.
# - Recommended products including the two best slushie machines for summer and the first affordable OLED monitor under $1,000.
#
# WIRED aims to provide its audience with comprehensive coverage of significant events and developments while fostering a deeper understanding of the interconnectedness of technology and society.
# # Engadget Summary
#
# Engadget focuses on delivering the latest technology news and product reviews. Recent headlines include a mix of significant developments in the tech and gaming industries:
#
# - **TikTok Ban Delay**: President Donald Trump has delayed a potential ban on TikTok for a third time, as the app still seeks a resolution regarding its future in the U.S.
# - **Bungie Delays Marathon**: The game developer Bungie has announced the indefinite delay of its upcoming title, Marathon.
# - **Nintendo Direct Announcement**: Nintendo unveiled a surprise character, Pauline, for the upcoming game "Donkey Kong Bananza" during a livestream.
# - **Google's New Features**: Google has launched its AI-powered Search Live feature on mobile apps, which allows voice input for searches.
# - **Updates on Popular Games**: There are significant updates regarding Hades II, which adds combat options, and confirmation that Beat Saber will no longer receive new content on PS VR and PS VR2.
# - **Amazon Prime Day Deals**: Prime Day is approaching with multiple deals including significant discounts on Audible subscriptions and other products.
#
# Additional articles covered various product reviews, such as the **Framework Laptop 12**, and discussions about emerging technology trends, like sleep tracking devices from Garmin and developments from Xbox's partnerships.
# # TNW | The Heart of Tech Summary
#
# TNW (The Next Web) is a prominent platform that focuses on the latest developments in technology, startups, and innovation. It serves as a hub for news, events, and resources concerning the tech industry. Key highlights from the site include:
#
# ## Upcoming Events
# - **TNW Conference**: Scheduled for June 19 & 20, 2025. The site encourages attendees to secure their tickets for this significant event in the tech calendar.
#
# ## Latest News
# - **Deep Tech and Sustainability**:
#   - A record investment by European VCs in a fusion energy project that stands out as promising.
#   - Finland plans to heat a town using the world's largest sand battery, demonstrating innovative sustainable practices.
# - **AI Developments**: UK executives have labeled AI as critically vital infrastructure, alongside essential resources like water and energy.
# - **Space and Defense**:
#   - The shift of space startups towards defense applications is noted as a catalyst for innovation.
#   - Sweden's first TNT factory since the Cold War is backed by notable Swedish investors.
# - **Ecosystem Insights**:
#   - A guide for startups on relocating to Valencia highlights emerging opportunities in that location.
#   - Discussions about how tech firms are navigating financial markets, including recent reluctance towards the London Stock Exchange.
#
# ## Opinion and Analysis
# Various opinion pieces address the importance of tech adaptation in sectors like defense and sustainability. The discussions showcase the evolving landscape of the tech ecosystem and its impact on society.
#
# TNW also offers a newsletter that delivers a weekly overview of the European tech scene, featuring insights and columns from its founders.
#
# Overall, TNW emphasizes a strong community connection in the tech space, promoting innovation and collaboration among startups, investors, and policymakers.
# # Ars Technica Overview
#
# Ars Technica is a technology-focused website that has been serving enthusiasts and professionals since 1998. It aims to deliver insightful news, reviews, and analyses across various sectors in technology and science, including AI, business and IT, gaming, culture, health, policy, science, security, and space.
#
# ## Recent Highlights
#
# ### Featured Articles
# - **Framework Laptop 12 Review**: The review highlights the sturdiness and thoughtful design of the laptop while noting its competitive disadvantages in pricing.
# - **Spanish Blackout Report**: A report on the Iberian blackout attributed the issue to grid management rather than the power sources themselves.
# - **Future of Xbox**: Discussion on why Microsoft’s next Xbox console should adopt a Windows-based system.
# - **Netflix Broadcasting Channels**: Announcement that Netflix will begin airing traditional broadcast channels starting next summer, particularly France's TF1 channels.
# - **Google Veo 3 Integration with YouTube Shorts**: News about Google's advanced AI video capabilities being integrated into YouTube Shorts.
#
# ### Significant Announcements
# - Former President Trump hinted at delays in a deal concerning TikTok, suggesting that only he can facilitate its sale.
# - New information about a Denisovan skull sheds light on this ancient human relative, previously unknown for decades.
# - Developments in the electric vehicle space with Audi's new models and Honda's entry into rocketry.
# - Scientists announced a catalog to preserve pre-AI content in light of growing concerns regarding AI's impact on original sources.
#
# Ars Technica continues to be a reliable resource for readers interested in the intricacies of technology and its implications in various fields.

# %%
# Define our system prompt for the combination and summaries


def generate_final_llm_messages(summaries):
    system_prompt = "You are an assistant will receive summaries of websites.  You will combine then into an integrated summary of the websites.  Please respond in markdown."
    user_prompt = "Combine these summaries into a single summary of the websites."

    for summary in summaries:
        user_prompt += "\n\n" + summary

    return [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt}
    ]

# %%
response = openai.chat.completions.create(
    model = "gpt-4o-mini",
    messages = generate_final_llm_messages(summaries)
)

final_response = response.choices[0].message.content

# %%
print(final_response)
# Out:
# # Integrated Summary of Technology Websites
#
# This summary amalgamates insights from various respected technology news platforms, providing a comprehensive overview of current trends, announcements, and innovations within the tech industry.
#
# ## Major Developments and Trends
#
# 1. **Investment and Manufacturing Initiatives**:
#    - **Texas Instruments** has pledged over **$60 billion** to bolster semiconductor manufacturing in the U.S., reflecting a significant commitment to domestic production amid ongoing supply chain challenges.
#    - European VCs are investing in breakthrough technologies, such as a fusion energy project and Finland's sand battery initiative for sustainable heating.
#
# 2. **Corporate Moves**:
#    - **Meta** is reportedly offering **$100 million** to attract talent from rival tech firms, showcasing competitive dynamics in the workforce.
#    - **Amazon** announced layoffs linked to improvements in AI efficiency, indicating shifts in workforce structures due to technological advancements.
#
# 3. **Emerging Technologies**:
#    - **Waymo** is progressing its robotaxi services, planning to launch in New York City, while **Nvidia** is revising its growth forecasts due to U.S. export controls affecting China.
#    - **Google** is enhancing its search capabilities with AI-powered voice chats, reflecting a trend towards more interactive and user-friendly interfaces.
#
# 4. **Legal and Regulatory Issues**:
#    - **Disney and Universal** are suing AI photo generator **Midjourney** over copyright infringement, signaling ongoing legal battles concerning AI's role in content creation.
#    - The need for regulatory oversight in AI development has been highlighted through discussions surrounding the "OpenAI Files", as policymakers examine the implications of artificial general intelligence (AGI).
#
# 5. **Cybersecurity and Infrastructure**:
#    - Reports of widespread internet disruptions in **Iran** and hacks targeting crypto exchanges underscore ongoing cybersecurity threats that impact financial systems worldwide.
#    - The **US Supreme Court** upheld a controversial ban on gender-affirming care for minors, reflecting broader societal and political challenges intersecting with technological and health issues.
#
# ## Startup and Innovation Insights
#
# - New startups like **Grifin** have raised funding to support investments tailored for female audiences, indicating a shift towards inclusivity in the tech investment landscape.
# - Prominent topics among investors include the evolving opportunities for AI startups, especially in light of recent fundraising trends during seed to Series C rounds.
#
# ## Notable Product Reviews and Features
#
# - Reviews of the **Framework Laptop 12** have emerged across several platforms, commending its sturdy design while noting competitive pricing issues.
# - Updates in the gaming sector include delays in upcoming titles from Bungie and insights into Nintendo’s new character reveal during livestreams.
#
# ## Cultural and Societal Commentary
#
# - **The Verge** and other platforms provide commentary on the implementation of warning labels on social media regarding mental health, addressing the societal concerns surrounding technology’s impact.
# - Articles also dissect the growing influence of AI on disinformation strategies during protests, illustrating the complex relationship between technology, culture, and society.
#
# ## Upcoming Events and Community Engagement
#
# - The TNW Conference is set for June 19 & 20, 2025, promoting innovation and collaboration within the tech ecosystem as stakeholders across industries gather to discuss emerging trends.
#
# Overall, the integrated summary reflects a landscape rich with investment, innovation, and dialogue surrounding the responsibilities and implications of technology within modern society. These platforms continue to serve as essential resources for anyone interested in the evolving intersections of technology and daily life.
